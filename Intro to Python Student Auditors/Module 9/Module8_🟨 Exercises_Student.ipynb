# %% [markdown]
# # Module 8: Introduction to Modeling Libraries in Python

# %%
# Many of the packages we'll need. Pay attention to what's here
# as you'll need to call some of them below.

# Data manipulation
import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical Packages
import statsmodels.api as sm
from statsmodels.api import OLS
from scipy.stats import ttest_ind, f_oneway, pearsonr, chi2_contingency, mannwhitneyu, wilcoxon, kruskal

# Machine Learning Packages
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
# !pip install bertopic
from IPython.display import clear_output
clear_output()
from bertopic import BERTopic

# For interacting with HuggingFace
from transformers import pipeline

# Set random seed for reproducibility
np.random.seed(42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 29
#      27 from IPython.display import clear_output
#      28 clear_output()
# ---> 29 from bertopic import BERTopic
#      31 # For interacting with HuggingFace
#      32 from transformers import pipeline
#
# ModuleNotFoundError: No module named 'bertopic'

# %%
# Read in the datasets for this lab. One df should be called "data" and the second
# should be called "textual_data".

# %%
# Before diving into modeling, it's always good to see what your data look like.
# Run sns.pairplot(data) to see if anything interesting stands out to you.

# %% [markdown]
# ### Basic Statistical Tests

# %%
# Q1: Conduct an independent t-test comparing improvement scores for two intervention types

# %%
# Q2: Conduct a one-way ANOVA to compare improvement scores across all intervention types

# %%
# Q3: Compute the Pearson correlation between session hours and improvement score

# %%
# Q4: First, add a new column to the data dataframe called hours_binned where you create three
# bins using the SessionHours column. The categories should be hours 0-10, 11-25, and 26+.
# Conduct a chi-square test for the distributions of intervention types
# (i.e., Do we see one more than the others?)

# %%
# Q5: Conduct a Mann-Whitney U test comparing improvement scores for two intervention types
# (non-parametric alternative to t-test)

# %%
# Q6: Conduct a Wilcoxon signed-rank test comparing sessio hours to improvement scores
# (requires paired data, using first 500 pairs)

# %%
# Q7: Conduct a Kruskal-Wallis H test comparing intervention type to improvement score
# (non-parametric alternative to ANOVA)

# %%
# Q8: Print your interpretation of each statistical test you conducted above

# %%
# Q9: Plot improvement trends by week for only the first five clients

# %%
# Q10: Fit a linear regression model from scikitlearn to predict improvement trends
# for all clients as a whole. The only predictor variable should be "Week"
# Print your interpretation of the output.

# %%
# Q11: Fit a linear regression model to predict improvement trends for the last five clients
# in the dataset, independently (i.e., build five models- one for each).
# Print your interpretation of the output.

# %%
# Q12: Fit a linear regression model from scikitlearn to predict improvement trends
# for all clients as a whole. The predictor variables should be "SessionHours", 'InterventionType',
# 'TrialsPerSession', 'ClientAge', 'NumberOfDiagnoses', and 'EmployeeYearsExperience'.
# HINT: You'll need to OneHotEncode one of these columns
# Print your interpretation of the output.

# %%
# Q13: Fit a random forest regression model from scikitlearn to predict improvement trends
# for all clients as a whole. The predictor variables should be "SessionHours", 'InterventionType',
# 'TrialsPerSession', 'ClientAge', 'NumberOfDiagnoses', and 'EmployeeYearsExperience'.
# HINT: You'll need to OneHotEncode one of these columns
# Print your interpretation of the output.

# %%
# Q14: Apply KMeans with three clusters from scikitlearn.
# Cluster using ClientAge and TrialsPerSession.
# Plot TrialsPerSession as a function of ClientAge

# %%
# Q15: Choose another unsupervised ML algorithm from scikit learn.
# Choose your preferred set of variables from the dataset to cluster on.
# Graph what you find.

# %% [markdown]
# ## Some NLP Work using the textual_data df [OPTIONAL BUT RECOMMENDED]

# %%
# Q16: Convert session notes into a bag-of-words representation using CountVectorizer
# Use english stop words. Limit to the top 50 words.
# Display the most common words

# %%
# Q17: Convert session notes into TF-IDF representation using TfidfVectorizer

# %%
# Q18: Fit LDA model with 5 topics using LatentDirichletAllocation (pass in the tfidf object
# you created using fit_transform in the previous question).
# Assign the most probable topic to each session note (.argmax will be useful here)
# Display the top 10 words associated with each topic

# %%
# Q19: Find clients associated with each topic using a chi-square analysis

# %%
# Q20: Load sentiment analysis pipeline from Hugging Face
# Perform sentiment analysis on session notes
# Display sentiment analysis results
# HINT: Running on GPU will speed this up

# %%
# Q21: Load topic modeling pipeline from Hugging Face
# Define potential topic labels
# Apply topic modeling to each session note
# Display topic classification results
# HINT: Running on GPU will speed this up
