# %% [markdown]
# # Module 1 - Lab Exercises

# %% [markdown]
# ### Understanding Structured Data

# %%
# List five different structured data formats discussed in Chapter 1.
# Store them in a Python list called `structured_data_formats`.
# Show the notebook reader that list

# %% [markdown]
# ### Installing Python Packages

# %%
# Import the following packages into your notebook using standard conventions:
# numpy, pandas, matplotlib, seaborn, scipy, scikit-learn, statsmodels

# %%
# For any one of the packages above, print a sentence that describes what it does

# %% [markdown]
# ### Interacting with the Command Line in a Notebook

# %%
# Write code that mimics interacting with the command line
# to check which version of python is installed.

# %%
# Write code that checks the list of items in the current directory you are in

# %%
# Print a statement that describes what the output is referencing

# %% [markdown]
# ### NumPy Basics

# %%
# Create a 1D NumPy array of the first 10 natural numbers.

# %%
# Print the 3rd and 7th element of the array you just created

# %%
# Create a 1D numpy array that contains all even numbers up to 10,000

# %%
# Create a 2D numpy array where one array contains all evens up to 1,000
# and the second array contains the square of the first array.

# %% [markdown]
# ### Pandas DataFrame

# %%
# Create a pandas DataFrame with two columns: 'Name' and 'Age',
# with at least three entries, and using dictionaries to populate the columns.

# %%
# Create a pandas DataFrame with two columns: 'Name' and 'Age',
# with at least three entries, and using lists to populate the columns.

# %%
# Select the age of the second person in the dataframe you created

# %%
# Select the name of the last person in the dataframe you created

# %% [markdown]
# ### Simple functions

# %%
# Write a simple function that adds two numbers together with proper
# documentation. Demonstrate its use.

# %%
# Write a simple function that multiplies two numbers
# together with proper documentation. Demonstrate its use.

# %%
# Write a simple function called 'integer_division' that
# divides a number but returns only the
# whole integer value, not any fractional remainder.
# Demonstrate its use with 10 divided by 3, and 25 divided by 4.

# %%
# Raise the output of integer_division for 25 divided by 4 to the third power
# and store it as a new object called "new_result".
# Show in code how you'd test whether new_result equals 260.

# %% [markdown]
# ### List Interactions

# %%
# Create a list of length five with mixed data types

# %%
# Add three more items to that list

# %%
# Print the data type for the fifth and last element in the list

# %%
# Prove whether your list is iterable

# %%
# Write a for loop that iterates through the list you created
# and prints the data type for every element in the list

# %%
# Create a list of squares of even numbers between 1 and 20 using list comprehension.

# %% [markdown]
# ### Advanced: Tying some things together

# %%
# Create a dataframe with 10 rows and three columns.
# The first column should be a sequence of dates between today and ten days from today.
# The second column should be the number of trials run during an ABA session.
#   - Use a random draw from a Gaussian distribution averageing 60
#     with a standard deviation of 10
# The third column should be the percentage of trials with correct responding.
#   - Use a random draw from uniform distribution with a low of 0 and high of 100.
